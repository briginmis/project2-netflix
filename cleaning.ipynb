# %%
import pandas as pd

# %%
movies = pd.read_csv("data/netflix-rotten-tomatoes-metacritic-imdb.csv")

# %%
print(movies)
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
movies.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
movies_clean = movies[['Title', 'Genre', 'Languages', 'Country Availability', 'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score', 'Boxoffice', 'Release Date', 'Poster', 'Trailer Site']]

# %%
movies_clean.dtypes
# Out:
# Title                     object
# Genre                     object
# Languages                 object
# Country Availability      object
# IMDb Score               float64
# Rotten Tomatoes Score    float64
# Metacritic Score         float64
# Boxoffice                 object
# Release Date              object
# Poster                    object
# Trailer Site              object
# dtype: object

# %%
movies_clean[['Title', 'Genre', 'Languages', 'Country Availability', 'Boxoffice', 'Release Date', 'Poster', 'Trailer Site']] = str(movies_clean[['Title', 'Genre', 'Languages', 'Country Availability', 'Boxoffice', 'Release Date', 'Poster', 'Trailer Site']])

# %%
#Create function to convert list in one cell to many rows

def explode_into_rows_in_new_table (input_df:pd.DataFrame,id_column, explode_column):

    # Create lists to store id and list of amenities
    id_list=[]
    explode_list=[]
    #iterate through each row and convert the string lists to actual lists using split function
    for index,row in input_df.iterrows():
        id_list.append(row[id_column])
        explode_list.append(row[explode_column].split(","))
    
    # Create a data frame from the id and amenities for each instance
    df2=pd.DataFrame({id_column:id_list,explode_column:explode_list})

    # Explode (split the lists into new rows)
    df2=df2.explode(explode_column)
    df2=df2.reset_index(drop=True)
    return df2

# %%
#Create function to clean prices, by removing dollar signs and commas
def clean_dollar(input_df, col_list):
    df=input_df.copy(deep=True)
    for col in col_list:
        df[col] = df[col].str.replace('$','')
        df[col] = df[col].str.replace(',','')
    return df

# %%
#Clean columns with multiple items

movies_clean_2 = explode_into_rows_in_new_table(input_df = movies_clean, id_column = "Title", explode_column = "Genre")

# %%
movies_clean_2
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                               Lets Fight Ghost
# 2                               Lets Fight Ghost
# 3                               Lets Fight Ghost
# 4                               Lets Fight Ghost
# ...                                          ...
# 263155  DreamWorks Kung Fu Panda Awesome Secrets
# 263156  DreamWorks Kung Fu Panda Awesome Secrets
# 263157  DreamWorks Kung Fu Panda Awesome Secrets
# 263158  DreamWorks Kung Fu Panda Awesome Secrets
# 263159  DreamWorks Kung Fu Panda Awesome Secrets
#
#                                                     Genre
# 0                                          0        Crime
# 1                                                   Drama
# 2                                                 Fantasy
# 3                                                  Horror
# 4        Romance\n1                                   ...
# ...
